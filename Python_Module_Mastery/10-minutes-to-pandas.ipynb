# %% [markdown]
# # 10 Minutes to pandas
#
# This is a short introduction to pandas, geared mainly for new users. You can see more complex recipes in the [Cookbook](http://pandas.pydata.org/pandas-docs/stable/cookbook.html#cookbook)
#
# pandas is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.
#
# pandas consists of the following elements
#
# + A set of labeled array data structures, the primary of which are Series and DataFrame
# + Index objects enabling both simple axis indexing and multi-level / hierarchical axis indexing
# + An integrated group by engine for aggregating and transforming data sets
# + Date range generation (date_range) and custom date offsets enabling the implementation of customized frequencies
# + Input/Output tools: loading tabular data from flat files (CSV, delimited, Excel 2003), and saving and loading pandas objects from the fast and efficient PyTables/HDF5 format.
# + Memory-efficient “sparse” versions of the standard data structures for storing data that is mostly missing or mostly constant (some fixed value)
# + Moving window statistics (rolling mean, rolling standard deviation, etc.)
#
# #### Data Structures
# | Dimensions        | Name           | Description  |
# | :-------------: |:-------------:| :-----|
# | 1      | Series | 1D labeled homogeneously-typed array |
# | 2      | DataFrame  |   General 2D labeled, size-mutable tabular structure with potentially heterogeneously-typed column |

# %% [markdown]
# Customarily, we import as follows:

# %%
import pandas as pd # import module as nickname is to use short hand or nickname to represent the module, here pd refers to pandas
import numpy as np #for linear algebra
import matplotlib.pyplot as plt #for plotting
# %matplotlib inline

# %% [markdown]
# ## Object Creation
#
# See the [Data Structure Intro section](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#dsintro)

# %% [markdown]
# ### Series
# **Series** is a one-dimensional labeled array capable of holding any data type (integers, strings, floating point numbers, Python objects, etc.). The axis labels are collectively referred to as the index. The basic method to create a Series is to call:
#
# > s = pd.Series(data, index=index)
#
# Here, data can be many different things:
# + a Python dict
# + an ndarray
# + a scalar value (like 5)
#
# Creating a Series by passing a list of values, letting pandas create a **default integer index**:

# %%
s = pd.Series([1,3,5,np.nan,6,8]) #nan means "not a number", np.nan can be regarded as a missing value

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# The first column in the output above is the "index", and the second column is the values, the last line indicates the data type.
#
# If data is a dictionary, if index is passed the values in data corresponding to the labels in the index will be pulled out. Otherwise, an index will be constructed from the sorted keys of the dict, if possible.

# %%
d = {'a' : 0., 'b' : 1., 'c' : 2.}

pd.Series(d)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
pd.Series(d, index=['b', 'c', 'd', 'a']) #There is no key 'd' in the dictionary, so the value is missing,or NaN
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %% [markdown]
# ### DataFrame
# **DataFrame** is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects. It is generally the most commonly used pandas object.
#
# DataFrame accepts many different kinds of input:
# + Dict of 1D ndarrays, lists, dicts, or Series
# + 2-D numpy.ndarray
# + Structured or record ndarray
# + A Series
# + Another DataFrame
#
# Along with the data, you can optionally pass index (row labels) and columns (column labels) arguments. If you pass an index and / or columns, you are guaranteeing the index and / or columns of the resulting DataFrame. Thus, a dict of Series plus a specific index will discard all data not matching up to the passed index.
#
# If axis labels are not passed, they will be constructed from the input data based on common sense rules.
#
# **Creating a DataFrame by passing a numpy array, with a datetime index and labeled columns:**

# %%
dates = pd.date_range('20130101', periods=6) #create a list of dates, starting from Jan. 1, 2013, for 6 days.

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
# np.random.randn(6,4) generates 6 by 4 random numbers array (6 rows and 4 columns). 
# The index are set to dates, columns are a list, which is equivalent to ['A','B','C','D'].
# If index is not specified, by default, it will be integers from 0 to number of rows minus one.

# %%
df
# Out:
#                    A         B          C          D
# 2000-01-01 -0.539385 -0.030653   0.691614  -0.960648
# 2000-01-02 -2.389843 -0.860333   1.586942  -1.683200
# 2000-01-03 -0.937021 -1.138231   2.225230  -2.931313
# 2000-01-04 -0.165181 -1.455484   0.224679  -0.947676
# 2000-01-05 -0.593457  0.717488  -1.505631  -0.659685
# 2000-01-06 -0.432809  1.731078  -3.132558  -2.630065
# 2000-01-07  0.034234  0.681146  -2.823004  -2.187019
# 2000-01-08 -0.346493 -0.801574  -3.222517  -2.720194
# 2000-01-09 -0.782730  1.077098  -3.732889  -2.319182
# 2000-01-10  1.927168  0.855470  -3.476926  -2.757321
# 2000-01-11  2.056116  2.454552  -1.922172  -2.457622
# 2000-01-12  2.992154  2.868425  -3.961066  -3.059053
# 2000-01-13  3.032141  1.704525  -6.108800  -3.515595
# 2000-01-14  4.386874  2.335490  -6.914661  -4.053384
# 2000-01-15  5.449254  2.127296  -6.960348  -5.058427
# 2000-01-16  6.423425  3.188096  -7.109299  -5.173396
# 2000-01-17  7.938761  4.479267  -8.558067  -4.574340
# 2000-01-18  8.428246  5.478835 -10.245033  -5.412923
# 2000-01-19  8.741308  5.201958 -11.594109  -6.114743
# 2000-01-20  8.883012  6.288470 -11.593434  -6.682205
# 2000-01-21  6.023708  6.139246  -9.760358  -5.985656
# 2000-01-22  7.599974  5.399313  -9.918257  -5.377863
# 2000-01-23  6.853464  6.865868 -10.645896  -3.090513
# 2000-01-24  6.161469  6.523691 -11.025570  -2.222151
# 2000-01-25  7.139732  5.949971 -10.740955  -3.145816
# 2000-01-26  6.383347  5.903617 -11.703566  -1.811331
# 2000-01-27  7.476623  4.660331 -11.043201  -1.499590
# 2000-01-28  6.316194  4.994445 -11.822399  -1.447972
# 2000-01-29  5.884328  3.276408 -12.208161  -0.790937
# 2000-01-30  7.799329  2.854066 -11.526053  -3.180541
# ...              ...       ...        ...        ...
# 2002-08-28  7.171685  0.137254 -42.352639 -36.141888
# 2002-08-29  6.125715  0.887744 -43.982931 -35.026615
# 2002-08-30  6.007902  2.059918 -43.918303 -35.878302
# 2002-08-31  3.449529  2.922784 -45.562737 -36.130046
# 2002-09-01  2.543320  1.143994 -43.383750 -35.982517
# 2002-09-02  1.276953  2.641648 -41.363923 -37.086579
# 2002-09-03 -1.127476  3.207179 -42.954287 -35.580656
# 2002-09-04 -0.675522  3.633222 -43.484031 -34.905728
# 2002-09-05 -0.693770  3.642376 -44.261159 -33.742692
# 2002-09-06 -1.337111  3.251880 -45.481411 -35.282793
# 2002-09-07  0.057937  2.080833 -45.822381 -35.329301
# 2002-09-08  0.421675  1.684977 -45.117125 -36.125921
# 2002-09-09  1.386282  0.788064 -47.094189 -35.960825
# 2002-09-10 -0.055373  1.843485 -46.000701 -34.403628
# 2002-09-11 -0.666481  1.785908 -47.836071 -33.897689
# 2002-09-12 -0.667668  2.645097 -48.628520 -32.902662
# 2002-09-13 -1.220343  2.012371 -48.611301 -33.477226
# 2002-09-14 -2.537486  0.869091 -47.375817 -33.617789
# 2002-09-15 -2.330425  0.973603 -46.920540 -33.596106
# 2002-09-16 -3.502756  0.594651 -44.555667 -33.033344
# 2002-09-17 -3.599015  1.627443 -44.160846 -33.444810
# 2002-09-18 -2.436417  0.384330 -45.600192 -32.275589
# 2002-09-19 -2.749606  0.129142 -45.041222 -33.270527
# 2002-09-20 -2.457621 -0.026389 -45.669013 -32.527948
# 2002-09-21 -2.389598 -0.488433 -45.313826 -32.926688
# 2002-09-22 -3.379581  0.384669 -46.959077 -33.869096
# 2002-09-23 -3.252299 -0.392102 -47.308016 -33.239235
# 2002-09-24 -2.870151 -1.229096 -48.788108 -34.181542
# 2002-09-25 -3.766273 -0.441975 -48.595779 -34.275645
# 2002-09-26 -2.265466 -1.958958 -48.680545 -33.646008
#
# [1000 rows x 4 columns]

# %% [markdown]
# **Creating a DataFrame by passing a dict of objects that can be converted to series-like.**

# %%
df2 = pd.DataFrame({'A':1.,
                   'B':pd.Timestamp('20130102'),
                   'C':pd.Series(1,index=list(range(4)),dtype='float32'),
                   'D':np.array([3]*4,dtype='int32'),
                   'E':pd.Categorical(["test","train","test","train"]),
                   'F':'foo'})

# %%
df2
import numpy

# %%
df.apply(numpy.cos)
# Out:
#                    A         B         C         D
# 2000-01-01  0.858025  0.999530  0.770217  0.572989
# 2000-01-02 -0.730495  0.652185 -0.016145 -0.112167
# 2000-01-03  0.592191  0.419202 -0.608710 -0.977973
# 2000-01-04  0.986389  0.115057  0.974866  0.583572
# 2000-01-05  0.829012  0.753460  0.065119  0.790185
# 2000-01-06  0.907791 -0.159597 -0.999959 -0.871998
# 2000-01-07  0.999414  0.776851 -0.949678 -0.577956
# 2000-01-08  0.940570  0.695577 -0.996727 -0.912518
# 2000-01-09  0.708991  0.473886 -0.830219 -0.680457
# 2000-01-10 -0.348877  0.655864 -0.944301 -0.927072
# 2000-01-11 -0.466491 -0.773126 -0.344189 -0.775070
# 2000-01-12 -0.988855 -0.962921 -0.682606 -0.996596
# 2000-01-13 -0.994016 -0.133331  0.984833 -0.930873
# 2000-01-14 -0.319797 -0.692316  0.807157 -0.612331
# 2000-01-15  0.671970 -0.528217  0.779354  0.339173
# 2000-01-16  0.990182 -0.998919  0.677738  0.444850
# 2000-01-17 -0.084678 -0.231016 -0.647337 -0.137611
# 2000-01-18 -0.543217  0.693580 -0.682035  0.644626
# 2000-01-19 -0.775386  0.470246  0.563433  0.985847
# 2000-01-20 -0.856799  0.999986  0.562875  0.921442
# 2000-01-21  0.966524  0.989659 -0.944219  0.956064
# 2000-01-22  0.251285  0.634162 -0.880690  0.617432
# 2000-01-23  0.841751  0.834989 -0.342596 -0.998696
# 2000-01-24  0.992602  0.971218  0.029991 -0.606264
# 2000-01-25  0.655051  0.944996 -0.251877 -0.999991
# 2000-01-26  0.994988  0.928825  0.650309 -0.238222
# 2000-01-27  0.368466 -0.052034  0.047609  0.071146
# 2000-01-28  0.999455  0.278331  0.735784  0.122515
# 2000-01-29  0.921506 -0.990926  0.936526  0.703179
# 2000-01-30  0.054625 -0.958948  0.505946 -0.999242
# ...              ...       ...       ...       ...
# 2002-08-28  0.630577  0.990595 -0.058828  0.013572
# 2002-08-29  0.987627  0.631163  1.000000 -0.891978
# 2002-08-30  0.962348 -0.469850  0.997953 -0.247417
# 2002-08-31 -0.952961 -0.976157 -0.009644  0.001730
# 2002-09-01 -0.826310  0.413962  0.826155 -0.145283
# 2002-09-02  0.289633 -0.877609 -0.866216  0.818194
# 2002-09-03  0.428941 -0.997850  0.516524 -0.520690
# 2002-09-04  0.780381 -0.881565  0.878412 -0.939985
# 2002-09-05  0.768841 -0.877207  0.961369 -0.685994
# 2002-09-06  0.231564 -0.993925  0.071622 -0.748318
# 2002-09-07  0.998322 -0.488209 -0.266045 -0.716669
# 2002-09-08  0.912404 -0.113933  0.422288 -0.002395
# 2002-09-09  0.183469  0.705219 -0.999559 -0.166709
# 2002-09-10  0.998467 -0.269322 -0.432810 -0.988182
# 2002-09-11  0.786002 -0.213457 -0.756938 -0.790097
# 2002-09-12  0.785268 -0.879257 -0.066118  0.083962
# 2002-09-13  0.343324 -0.427364 -0.083289 -0.471070
# 2002-09-14 -0.823010  0.645521 -0.968434 -0.590006
# 2002-09-15 -0.688652  0.562324 -0.979395 -0.572361
# 2002-09-16 -0.935486  0.828344  0.840077 -0.046604
# 2002-09-17 -0.897194 -0.056617  0.984102 -0.442233
# 2002-09-18 -0.761498  0.927050 -0.047081  0.652693
# 2002-09-19 -0.924152  0.991673  0.489809 -0.280010
# 2002-09-20 -0.775069  0.999652 -0.115660  0.442850
# 2002-09-21 -0.730328  0.883069  0.236991  0.059999
# 2002-09-22 -0.971814  0.926923 -0.986449 -0.772249
# 2002-09-23 -0.993878  0.924108 -0.983097 -0.249838
# 2002-09-24 -0.963385  0.335090  0.093286 -0.930149
# 2002-09-25 -0.811150  0.903909 -0.098746 -0.960536
# 2002-09-26 -0.640132 -0.378487 -0.014140 -0.612552
#
# [1000 rows x 4 columns]

# %% [markdown]
# #### Check the shape of the datafram
# df.shape returns two numbers, first number is the number of rows, second number is the number of columns

# %%
df.shape
# Out:
# (6, 4)

# %% [markdown]
# Having specific [dtypes](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-dtypes)

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# If you’re using IPython, tab completion for column names (as well as public attributes) is automatically enabled. Here’s a subset of the attributes that will be completed:

# %%
# df2.<TAB>

# %% [markdown]
# As you can see, the columns A, B, C, and D are automatically tab completed. E is there as well; the rest of the attributes have been truncated for brevity.

# %% [markdown]
# ## Viewing Data
#
# See the [Basics section](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics)

# %% [markdown]
# See the top & bottom rows of the frame

# %%
df.head() # by default, df.head() display the first 5 rows of data.
# Out:
#                    A         B         C         D
# 2013-01-01  0.538825 -1.250193  1.450528 -1.129132
# 2013-01-02  0.685796 -0.911191  0.644460 -0.457984
# 2013-01-03 -0.017453 -1.348909 -0.087432 -0.473689
# 2013-01-04  0.128924 -0.140735 -0.830578 -0.103705
# 2013-01-05  1.025420 -0.242100 -0.646547 -1.452282

# %%
df.tail(3) # by default, df.tail() display the last 5 rows of data, but you can change how many to display.
# Out:
#                    A         B         C         D
# 2013-01-04  0.128924 -0.140735 -0.830578 -0.103705
# 2013-01-05  1.025420 -0.242100 -0.646547 -1.452282
# 2013-01-06 -2.243299  0.987909  0.472630 -0.082991

# %% [markdown]
# **Display the index, columns, and the underlying numpy data**

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.values
# Out:
# array([[ 0.53882536, -1.25019251,  1.45052762, -1.12913186],
#        [ 0.68579573, -0.91119139,  0.64445996, -0.45798419],
#        [-0.01745339, -1.34890905, -0.08743182, -0.47368862],
#        [ 0.12892448, -0.14073527, -0.83057819, -0.10370478],
#        [ 1.02542035, -0.24210023, -0.64654679, -1.452282  ],
#        [-2.24329855,  0.98790868,  0.47262957, -0.08299144]])

# %% [markdown]
# #### Describe shows a quick statistic summary of your data

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.019702 -0.484203  0.167177 -0.616630
# std    1.171249  0.878689  0.859136  0.557573
# min   -2.243299 -1.348909 -0.830578 -1.452282
# 25%    0.019141 -1.165442 -0.506768 -0.965271
# 50%    0.333875 -0.576646  0.192599 -0.465836
# 75%    0.649053 -0.166077  0.601502 -0.192275
# max    1.025420  0.987909  1.450528 -0.082991

# %% [markdown]
# **Transposing your data**

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.538825    0.685796   -0.017453    0.128924    1.025420   -2.243299
# B   -1.250193   -0.911191   -1.348909   -0.140735   -0.242100    0.987909
# C    1.450528    0.644460   -0.087432   -0.830578   -0.646547    0.472630
# D   -1.129132   -0.457984   -0.473689   -0.103705   -1.452282   -0.082991

# %% [markdown]
# **Sorting by an axis**
#
# When axis=1 it refers to row-wise, and axis=0, it refers to colomn-wise
#
# sort_index is to sort on index or column names, **Not on value**

# %%
df.sort_index(axis=1, ascending=False) #by default sort is ascending
# Out:
#                    D         C         B         A
# 2013-01-01 -1.129132  1.450528 -1.250193  0.538825
# 2013-01-02 -0.457984  0.644460 -0.911191  0.685796
# 2013-01-03 -0.473689 -0.087432 -1.348909 -0.017453
# 2013-01-04 -0.103705 -0.830578 -0.140735  0.128924
# 2013-01-05 -1.452282 -0.646547 -0.242100  1.025420
# 2013-01-06 -0.082991  0.472630  0.987909 -2.243299

# %%
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2013-01-06 -2.243299  0.987909  0.472630 -0.082991
# 2013-01-05  1.025420 -0.242100 -0.646547 -1.452282
# 2013-01-04  0.128924 -0.140735 -0.830578 -0.103705
# 2013-01-03 -0.017453 -1.348909 -0.087432 -0.473689
# 2013-01-02  0.685796 -0.911191  0.644460 -0.457984
# 2013-01-01  0.538825 -1.250193  1.450528 -1.129132

# %% [markdown]
# **Sorting by value**

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-03 -0.017453 -1.348909 -0.087432 -0.473689
# 2013-01-01  0.538825 -1.250193  1.450528 -1.129132
# 2013-01-02  0.685796 -0.911191  0.644460 -0.457984
# 2013-01-05  1.025420 -0.242100 -0.646547 -1.452282
# 2013-01-04  0.128924 -0.140735 -0.830578 -0.103705
# 2013-01-06 -2.243299  0.987909  0.472630 -0.082991

# %%
df['B']=[1,3,2,1,2,3] #change the value of column B to [1,3,2,1,2,3]

# %%
df
# Out:
#                    A  B         C         D
# 2013-01-01  0.538825  1  1.450528 -1.129132
# 2013-01-02  0.685796  3  0.644460 -0.457984
# 2013-01-03 -0.017453  2 -0.087432 -0.473689
# 2013-01-04  0.128924  1 -0.830578 -0.103705
# 2013-01-05  1.025420  2 -0.646547 -1.452282
# 2013-01-06 -2.243299  3  0.472630 -0.082991

# %%
df.sort_values(by=['B','D'],ascending=[True,False]) # sort values first by column B ascendingly then by column D descendingly.
# Out:
#                    A  B         C         D
# 2013-01-04  0.128924  1 -0.830578 -0.103705
# 2013-01-01  0.538825  1  1.450528 -1.129132
# 2013-01-03 -0.017453  2 -0.087432 -0.473689
# 2013-01-05  1.025420  2 -0.646547 -1.452282
# 2013-01-06 -2.243299  3  0.472630 -0.082991
# 2013-01-02  0.685796  3  0.644460 -0.457984

# %% [markdown]
# ## Selection

# %% [markdown]
# **Note:** While standard Python / Numpy expressions for selecting and setting are intuitive and come in handy for interactive work, for production code, we recommend the optimized pandas data access methods, .at, .iat, .loc, .iloc and .ix.

# %% [markdown]
# See the indexing documentation [Indexing and Selecting Data](http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing) and [MultiIndex / Advanced Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html#advanced)

# %% [markdown]
# ### Getting

# %% [markdown]
# Selecting a single column, which yields a Series, equivalent to df.A

# %%
df['A']
# Out:
# 2013-01-01    0.538825
# 2013-01-02    0.685796
# 2013-01-03   -0.017453
# 2013-01-04    0.128924
# 2013-01-05    1.025420
# 2013-01-06   -2.243299
# Freq: D, Name: A, dtype: float64

# %% [markdown]
# Selecting more than one columns.

# %%
df[['A','B']]
# Out:
#                    A  B
# 2013-01-01  0.538825  1
# 2013-01-02  0.685796  3
# 2013-01-03 -0.017453  2
# 2013-01-04  0.128924  1
# 2013-01-05  1.025420  2
# 2013-01-06 -2.243299  3

# %% [markdown]
# Selecting via [], which slices the rows.

# %%
df[0:3]
# Out:
#                    A  B         C         D
# 2013-01-01  0.538825  1  1.450528 -1.129132
# 2013-01-02  0.685796  3  0.644460 -0.457984
# 2013-01-03 -0.017453  2 -0.087432 -0.473689

# %%
df['20130102':'20130104']
# Out:
#                    A  B         C         D
# 2013-01-02  0.685796  3  0.644460 -0.457984
# 2013-01-03 -0.017453  2 -0.087432 -0.473689
# 2013-01-04  0.128924  1 -0.830578 -0.103705

# %% [markdown]
# ### Selection by Label
#
# See more in [Selection by Label](Selection by Label)

# %% [markdown]
# For getting a cross section using a label
#
# `df.loc[start:end]` selects the rows based on index, between start and end, **both endpoints are included.**

# %%
df.loc[dates[0]]# select the row where the index is date[0], in our example, it is 2013-01-01.
# Out:
# A    0.538825
# B    1.000000
# C    1.450528
# D   -1.129132
# Name: 2013-01-01 00:00:00, dtype: float64

# %% [markdown]
# Selection by Label
# `df.loc[,]` inside the [], before ',' you can specify index, after ',' you can specify columns to be selected.

# %%
df.loc[:,['A','B']] #select all row, but only columns 'A' and "B'.
# Out:
#                    A  B
# 2013-01-01  0.538825  1
# 2013-01-02  0.685796  3
# 2013-01-03 -0.017453  2
# 2013-01-04  0.128924  1
# 2013-01-05  1.025420  2
# 2013-01-06 -2.243299  3

# %% [markdown]
# Showing label slicing, **both endpoints are included**

# %%
df.loc['20130102':'20130104',['A','B']] #select rows between 2013-01-02 to 2013-01-04,
# Out:
#                    A  B
# 2013-01-02  0.685796  3
# 2013-01-03 -0.017453  2
# 2013-01-04  0.128924  1

# %% [markdown]
# For getting a scalar value

# %%
df.loc[dates[0],'A']
# Out:
# 0.53882535940396636

# %% [markdown]
# ### Selection by Position
#
# See more in [Selection by Position](http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-integer)

# %% [markdown]
# Select via the position of the passed integers
#
# `df.iloc[,]` selects rows/columns based on position of rows/columns, e.g., df.iloc[3,5] selects the fouth row and 6th column of the data, remember it starts at 0.

# %%
df.iloc[3]
# Out:
# A    0.128924
# B    1.000000
# C   -0.830578
# D   -0.103705
# Name: 2013-01-04 00:00:00, dtype: float64

# %% [markdown]
# By integer slices, acting similar to numpy/python
#
# **When use `df.iloc[start:end]`, end is NOT included, different from `df.loc[]`!**

# %%
df.iloc[3:5,0:2] #selects 4th and 5th rows, and first, second columns.
# Out:
#                    A  B
# 2013-01-04  0.128924  1
# 2013-01-05  1.025420  2

# %% [markdown]
# By lists of integer position locations, similar to the numpy/python style

# %%
df.iloc[[1,2,4],[0,2]] #select 2nd, 3rd, and 5th rows, and first, third columns
# Out:
#                    A         C
# 2013-01-02  0.685796  0.644460
# 2013-01-03 -0.017453 -0.087432
# 2013-01-05  1.025420 -0.646547

# %% [markdown]
# For slicing rows explicitly

# %%
df.iloc[1:3,:] #select second, third rows and all columns.
# Out:
#                    A  B         C         D
# 2013-01-02  0.685796  3  0.644460 -0.457984
# 2013-01-03 -0.017453  2 -0.087432 -0.473689

# %% [markdown]
# For slicing columns explicitly

# %%
df.iloc[:,1:3]
# Out:
#             B         C
# 2013-01-01  1  1.450528
# 2013-01-02  3  0.644460
# 2013-01-03  2 -0.087432
# 2013-01-04  1 -0.830578
# 2013-01-05  2 -0.646547
# 2013-01-06  3  0.472630

# %% [markdown]
# For getting a value explicitly

# %%
df.iloc[1,1]
# Out:
# 3

# %% [markdown]
# For getting fast access to a scalar (equiv to the prior method)

# %%
df.iat[1,1]
# Out:
# 3

# %% [markdown]
# ## Boolean Indexing

# %% [markdown]
# Using a single column’s values to select data.

# %%
df[df.A > 0] #select rows where column A's value is greater than 0.
# Out:
#                    A  B         C         D
# 2013-01-01  0.538825  1  1.450528 -1.129132
# 2013-01-02  0.685796  3  0.644460 -0.457984
# 2013-01-04  0.128924  1 -0.830578 -0.103705
# 2013-01-05  1.025420  2 -0.646547 -1.452282

# %% [markdown]
# A where operation for getting.

# %%
df[df > 0] #select values that are greater than 0, if smaller or equal to 0, then the value becomes NaN (not a number or missing)
# Out:
#                    A  B         C   D
# 2013-01-01  0.538825  1  1.450528 NaN
# 2013-01-02  0.685796  3  0.644460 NaN
# 2013-01-03       NaN  2       NaN NaN
# 2013-01-04  0.128924  1       NaN NaN
# 2013-01-05  1.025420  2       NaN NaN
# 2013-01-06       NaN  3  0.472630 NaN

# %% [markdown]
# Using the isin() method for filtering:

# %%
df2 = df.copy()

# %%
df2['E'] = ['one','one', 'two','three','four','three']

# %%
df2
# Out:
#                    A  B         C         D      E
# 2013-01-01  0.538825  1  1.450528 -1.129132    one
# 2013-01-02  0.685796  3  0.644460 -0.457984    one
# 2013-01-03 -0.017453  2 -0.087432 -0.473689    two
# 2013-01-04  0.128924  1 -0.830578 -0.103705  three
# 2013-01-05  1.025420  2 -0.646547 -1.452282   four
# 2013-01-06 -2.243299  3  0.472630 -0.082991  three

# %%
df2[df2['E'].isin(['two','four'])]
# Out:
#                    A  B         C         D     E
# 2013-01-03 -0.017453  2 -0.087432 -0.473689   two
# 2013-01-05  1.025420  2 -0.646547 -1.452282  four

# %% [markdown]
# ## Setting

# %% [markdown]
# Setting a new column automatically aligns the data by the indexes

# %%
s1 = pd.Series([1,2,3,4,5,6], index=pd.date_range('20130102',periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df['F'] = s1 #Assign s1 to the F column of df

# %% [markdown]
# Setting values by label

# %%
df.at[dates[0],'A'] = 0

# %% [markdown]
# Setting values by position

# %%
df.iat[0,1] = 0

# %% [markdown]
# Setting by assigning with a numpy array

# %%
df.loc[:,'D'] = np.array([5] * len(df))

# %% [markdown]
# The result of the prior setting operations

# %%
df
# Out:
#                    A  B         C  D    F
# 2013-01-01  0.000000  0  1.450528  5  NaN
# 2013-01-02  0.685796  3  0.644460  5  1.0
# 2013-01-03 -0.017453  2 -0.087432  5  2.0
# 2013-01-04  0.128924  1 -0.830578  5  3.0
# 2013-01-05  1.025420  2 -0.646547  5  4.0
# 2013-01-06 -2.243299  3  0.472630  5  5.0

# %% [markdown]
# **A where operation with setting.**

# %%
df2 = df.copy() #make a copy of df

# %%
df2[df2 > 0] = -df2 #change the sign of positive values of df to negative, where the vale is greater than 0.

# %%
df2
# Out:
#                    A  B         C  D    F
# 2013-01-01  0.000000  0 -1.450528 -5  NaN
# 2013-01-02 -0.685796 -3 -0.644460 -5 -1.0
# 2013-01-03 -0.017453 -2 -0.087432 -5 -2.0
# 2013-01-04 -0.128924 -1 -0.830578 -5 -3.0
# 2013-01-05 -1.025420 -2 -0.646547 -5 -4.0
# 2013-01-06 -2.243299 -3 -0.472630 -5 -5.0

# %% [markdown]
# ## Missing Data
#
# pandas primarily uses the value np.nan to represent missing data. It is by default not included in computations. See the Missing Data section

# %% [markdown]
# Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data.

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])

# %%
df1.loc[dates[0]:dates[1],'E'] = 1

# %%
df1
# Out:
#                    A  B         C  D    F    E
# 2013-01-01  0.000000  0  1.450528  5  NaN  1.0
# 2013-01-02  0.685796  3  0.644460  5  1.0  1.0
# 2013-01-03 -0.017453  2 -0.087432  5  2.0  NaN
# 2013-01-04  0.128924  1 -0.830578  5  3.0  NaN

# %% [markdown]
# To drop any rows that have missing data.

# %%
df1.dropna(how='any')
# Out:
#                    A  B        C  D    F    E
# 2013-01-02  0.685796  3  0.64446  5  1.0  1.0

# %% [markdown]
# Filling missing data

# %%
df1.fillna(value=5)
# Out:
#                    A  B         C  D    F    E
# 2013-01-01  0.000000  0  1.450528  5  5.0  1.0
# 2013-01-02  0.685796  3  0.644460  5  1.0  1.0
# 2013-01-03 -0.017453  2 -0.087432  5  2.0  5.0
# 2013-01-04  0.128924  1 -0.830578  5  3.0  5.0

# %% [markdown]
# To get the boolean mask where values are nan

# %%
pd.isnull(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# ## Operations
#
# See the [Basic section on Binary Ops](http://pandas.pydata.org/pandas-docs/stable/basics.html#basics-binop)

# %% [markdown]
# ### Stats
#
# Operations in general exclude missing data.

# %% [markdown]
# **Performing a descriptive statistic**

# %%
df.mean() #by default, it returns the mean along columns
# Out:
# A   -0.070102
# B    1.833333
# C    0.167177
# D    5.000000
# F    3.000000
# dtype: float64

# %% [markdown]
# Same operation on the other axis
#
# When you specify axis=1, it returns the mean along rows, by default axis=0 which refers to column.

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    1.612632
# 2013-01-02    2.066051
# 2013-01-03    1.779023
# 2013-01-04    1.659669
# 2013-01-05    2.275775
# 2013-01-06    2.245866
# Freq: D, dtype: float64

# %% [markdown]
# Operating with objects that have different dimensionality and need alignment. In addition, pandas automatically broadcasts along the specified dimension.

# %%
s = pd.Series([1,3,5,np.nan,6,8], index=dates).shift(2) #shift the value down 2 rows.

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A    B         C    D    F
# 2013-01-01       NaN  NaN       NaN  NaN  NaN
# 2013-01-02       NaN  NaN       NaN  NaN  NaN
# 2013-01-03 -1.017453  1.0 -1.087432  4.0  1.0
# 2013-01-04 -2.871076 -2.0 -3.830578  2.0  0.0
# 2013-01-05 -3.974580 -3.0 -5.646547  0.0 -1.0
# 2013-01-06       NaN  NaN       NaN  NaN  NaN

# %% [markdown]
# ### Apply

# %% [markdown]
# Applying functions to the data

# %%
df
# Out:
#                    A  B         C  D    F
# 2013-01-01  0.000000  0  1.450528  5  NaN
# 2013-01-02  0.685796  3  0.644460  5  1.0
# 2013-01-03 -0.017453  2 -0.087432  5  2.0
# 2013-01-04  0.128924  1 -0.830578  5  3.0
# 2013-01-05  1.025420  2 -0.646547  5  4.0
# 2013-01-06 -2.243299  3  0.472630  5  5.0

# %%
df.apply(np.cumsum) # apply cumulative sum or rolling sum to each column
# Out:
#                    A   B         C   D     F
# 2013-01-01  0.000000   0  1.450528   5   NaN
# 2013-01-02  0.685796   3  2.094988  10   1.0
# 2013-01-03  0.668342   5  2.007556  15   3.0
# 2013-01-04  0.797267   6  1.176978  20   6.0
# 2013-01-05  1.822687   8  0.530431  25  10.0
# 2013-01-06 -0.420611  11  1.003060  30  15.0

# %% [markdown]
# ## Merge

# %% [markdown]
# ### Concat
#
# pandas provides various facilities for easily combining together Series, DataFrame, and Panel objects with various kinds of set logic for the indexes and relational algebra functionality in the case of join / merge-type operations.
#
# See the [Merging section](http://pandas.pydata.org/pandas-docs/stable/merging.html#merging)

# %% [markdown]
# Concatenating pandas objects together with concat():

# %%
df = pd.DataFrame(np.random.randn(10, 4),columns=list('ABCD'))

# %%
df
# Out:
#           A         B         C         D
# 0 -0.575295  0.466285 -1.164486 -0.149937
# 1 -1.546530 -1.576939 -1.075116  0.242190
# 2 -0.661757 -0.931619  0.683207 -0.123539
# 3  0.103069  1.609480 -0.711672 -1.464863
# 4 -0.115005  0.971593  0.710370 -0.741819
# 5 -0.176920  0.043678 -0.384216  0.409628
# 6  0.401929 -1.871732  1.924167  0.961387
# 7  0.942661  0.169705  1.075921 -0.124877
# 8 -0.876986  0.086462 -0.176276  2.181330
# 9 -2.336410 -1.126014 -0.492160  0.074342

# %%
# break it into pieces
a = df[:3]
b = df[3:7]
c = df[7:]
pieces = [a,b,c]

# %%
df2=pd.concat(pieces)
df2
# Out:
#           A         B         C         D
# 0 -0.575295  0.466285 -1.164486 -0.149937
# 1 -1.546530 -1.576939 -1.075116  0.242190
# 2 -0.661757 -0.931619  0.683207 -0.123539
# 3  0.103069  1.609480 -0.711672 -1.464863
# 4 -0.115005  0.971593  0.710370 -0.741819
# 5 -0.176920  0.043678 -0.384216  0.409628
# 6  0.401929 -1.871732  1.924167  0.961387
# 7  0.942661  0.169705  1.075921 -0.124877
# 8 -0.876986  0.086462 -0.176276  2.181330
# 9 -2.336410 -1.126014 -0.492160  0.074342

# %% [markdown]
# ### Join
#
# SQL style merges. See the [Database style joining](http://pandas.pydata.org/pandas-docs/stable/merging.html#merging-join)

# %%
left = pd.DataFrame({'key': ['foo', 'foo','boo','boo','coo'], 'lval': [1, 2,3,4,5]})

# %%
right = pd.DataFrame({'key': ['foo', 'boo','doo'], 'rval': [6,7,8]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2
# 2  boo     3
# 3  boo     4
# 4  coo     5

# %%
right
# Out:
#    key  rval
# 0  foo     6
# 1  boo     7
# 2  doo     8

# %%
pd.merge(left, right, on='key',how='left')
# Out:
#    key  lval  rval
# 0  foo     1   6.0
# 1  foo     2   6.0
# 2  boo     3   7.0
# 3  boo     4   7.0
# 4  coo     5   NaN

# %%
pd.merge(left, right, on='key',how='right')
# Out:
#    key  lval  rval
# 0  foo   1.0     6
# 1  foo   2.0     6
# 2  boo   3.0     7
# 3  boo   4.0     7
# 4  doo   NaN     8

# %%
pd.merge(left, right, on='key',how='outer')
# Out:
#    key  lval  rval
# 0  foo   1.0   6.0
# 1  foo   2.0   6.0
# 2  boo   3.0   7.0
# 3  boo   4.0   7.0
# 4  coo   5.0   NaN
# 5  doo   NaN   8.0

# %%
pd.merge(left, right, on='key',how='inner')
# Out:
#    key  lval  rval
# 0  foo     1     6
# 1  foo     2     6
# 2  boo     3     7
# 3  boo     4     7

# %% [markdown]
# ## Plotting
# [Plotting](http://pandas.pydata.org/pandas-docs/stable/visualization.html#visualization) docs.

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %% [markdown]
# On DataFrame, plot() is a convenience to plot all of the columns with labels:

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                  columns=['A', 'B', 'C', 'D'])

# %%
df = df.cumsum()

# %%
plt.figure(); df.plot(); plt.legend(loc='best')

# %% [markdown]
# ## Getting Data In/Out

# %% [markdown]
# ### CSV
# [Writing to a csv file](http://pandas.pydata.org/pandas-docs/stable/io.html#io-store-in-csv)

# %%
df.to_csv('foo.csv',index=False)

# %%
pwd
# Out:
# 'C:\\Users\\Jared\\Desktop'

# %%
df
# Out:
#                    A         B          C          D
# 2000-01-01 -0.539385 -0.030653   0.691614  -0.960648
# 2000-01-02 -2.389843 -0.860333   1.586942  -1.683200
# 2000-01-03 -0.937021 -1.138231   2.225230  -2.931313
# 2000-01-04 -0.165181 -1.455484   0.224679  -0.947676
# 2000-01-05 -0.593457  0.717488  -1.505631  -0.659685
# 2000-01-06 -0.432809  1.731078  -3.132558  -2.630065
# 2000-01-07  0.034234  0.681146  -2.823004  -2.187019
# 2000-01-08 -0.346493 -0.801574  -3.222517  -2.720194
# 2000-01-09 -0.782730  1.077098  -3.732889  -2.319182
# 2000-01-10  1.927168  0.855470  -3.476926  -2.757321
# 2000-01-11  2.056116  2.454552  -1.922172  -2.457622
# 2000-01-12  2.992154  2.868425  -3.961066  -3.059053
# 2000-01-13  3.032141  1.704525  -6.108800  -3.515595
# 2000-01-14  4.386874  2.335490  -6.914661  -4.053384
# 2000-01-15  5.449254  2.127296  -6.960348  -5.058427
# 2000-01-16  6.423425  3.188096  -7.109299  -5.173396
# 2000-01-17  7.938761  4.479267  -8.558067  -4.574340
# 2000-01-18  8.428246  5.478835 -10.245033  -5.412923
# 2000-01-19  8.741308  5.201958 -11.594109  -6.114743
# 2000-01-20  8.883012  6.288470 -11.593434  -6.682205
# 2000-01-21  6.023708  6.139246  -9.760358  -5.985656
# 2000-01-22  7.599974  5.399313  -9.918257  -5.377863
# 2000-01-23  6.853464  6.865868 -10.645896  -3.090513
# 2000-01-24  6.161469  6.523691 -11.025570  -2.222151
# 2000-01-25  7.139732  5.949971 -10.740955  -3.145816
# 2000-01-26  6.383347  5.903617 -11.703566  -1.811331
# 2000-01-27  7.476623  4.660331 -11.043201  -1.499590
# 2000-01-28  6.316194  4.994445 -11.822399  -1.447972
# 2000-01-29  5.884328  3.276408 -12.208161  -0.790937
# 2000-01-30  7.799329  2.854066 -11.526053  -3.180541
# ...              ...       ...        ...        ...
# 2002-08-28  7.171685  0.137254 -42.352639 -36.141888
# 2002-08-29  6.125715  0.887744 -43.982931 -35.026615
# 2002-08-30  6.007902  2.059918 -43.918303 -35.878302
# 2002-08-31  3.449529  2.922784 -45.562737 -36.130046
# 2002-09-01  2.543320  1.143994 -43.383750 -35.982517
# 2002-09-02  1.276953  2.641648 -41.363923 -37.086579
# 2002-09-03 -1.127476  3.207179 -42.954287 -35.580656
# 2002-09-04 -0.675522  3.633222 -43.484031 -34.905728
# 2002-09-05 -0.693770  3.642376 -44.261159 -33.742692
# 2002-09-06 -1.337111  3.251880 -45.481411 -35.282793
# 2002-09-07  0.057937  2.080833 -45.822381 -35.329301
# 2002-09-08  0.421675  1.684977 -45.117125 -36.125921
# 2002-09-09  1.386282  0.788064 -47.094189 -35.960825
# 2002-09-10 -0.055373  1.843485 -46.000701 -34.403628
# 2002-09-11 -0.666481  1.785908 -47.836071 -33.897689
# 2002-09-12 -0.667668  2.645097 -48.628520 -32.902662
# 2002-09-13 -1.220343  2.012371 -48.611301 -33.477226
# 2002-09-14 -2.537486  0.869091 -47.375817 -33.617789
# 2002-09-15 -2.330425  0.973603 -46.920540 -33.596106
# 2002-09-16 -3.502756  0.594651 -44.555667 -33.033344
# 2002-09-17 -3.599015  1.627443 -44.160846 -33.444810
# 2002-09-18 -2.436417  0.384330 -45.600192 -32.275589
# 2002-09-19 -2.749606  0.129142 -45.041222 -33.270527
# 2002-09-20 -2.457621 -0.026389 -45.669013 -32.527948
# 2002-09-21 -2.389598 -0.488433 -45.313826 -32.926688
# 2002-09-22 -3.379581  0.384669 -46.959077 -33.869096
# 2002-09-23 -3.252299 -0.392102 -47.308016 -33.239235
# 2002-09-24 -2.870151 -1.229096 -48.788108 -34.181542
# 2002-09-25 -3.766273 -0.441975 -48.595779 -34.275645
# 2002-09-26 -2.265466 -1.958958 -48.680545 -33.646008
#
# [1000 rows x 4 columns]

# %% [markdown]
# [Reading from a csv file](http://pandas.pydata.org/pandas-docs/stable/io.html#io-read-csv-table)

# %%
pd.read_csv('foo.csv')
# Out:
#             A         B          C          D
# 0   -0.539385 -0.030653   0.691614  -0.960648
# 1   -2.389843 -0.860333   1.586942  -1.683200
# 2   -0.937021 -1.138231   2.225230  -2.931313
# 3   -0.165181 -1.455484   0.224679  -0.947676
# 4   -0.593457  0.717488  -1.505631  -0.659685
# 5   -0.432809  1.731078  -3.132558  -2.630065
# 6    0.034234  0.681146  -2.823004  -2.187019
# 7   -0.346493 -0.801574  -3.222517  -2.720194
# 8   -0.782730  1.077098  -3.732889  -2.319182
# 9    1.927168  0.855470  -3.476926  -2.757321
# 10   2.056116  2.454552  -1.922172  -2.457622
# 11   2.992154  2.868425  -3.961066  -3.059053
# 12   3.032141  1.704525  -6.108800  -3.515595
# 13   4.386874  2.335490  -6.914661  -4.053384
# 14   5.449254  2.127296  -6.960348  -5.058427
# 15   6.423425  3.188096  -7.109299  -5.173396
# 16   7.938761  4.479267  -8.558067  -4.574340
# 17   8.428246  5.478835 -10.245033  -5.412923
# 18   8.741308  5.201958 -11.594109  -6.114743
# 19   8.883012  6.288470 -11.593434  -6.682205
# 20   6.023708  6.139246  -9.760358  -5.985656
# 21   7.599974  5.399313  -9.918257  -5.377863
# 22   6.853464  6.865868 -10.645896  -3.090513
# 23   6.161469  6.523691 -11.025570  -2.222151
# 24   7.139732  5.949971 -10.740955  -3.145816
# 25   6.383347  5.903617 -11.703566  -1.811331
# 26   7.476623  4.660331 -11.043201  -1.499590
# 27   6.316194  4.994445 -11.822399  -1.447972
# 28   5.884328  3.276408 -12.208161  -0.790937
# 29   7.799329  2.854066 -11.526053  -3.180541
# ..        ...       ...        ...        ...
# 970  7.171685  0.137254 -42.352639 -36.141888
# 971  6.125715  0.887744 -43.982931 -35.026615
# 972  6.007902  2.059918 -43.918303 -35.878302
# 973  3.449529  2.922784 -45.562737 -36.130046
# 974  2.543320  1.143994 -43.383750 -35.982517
# 975  1.276953  2.641648 -41.363923 -37.086579
# 976 -1.127476  3.207179 -42.954287 -35.580656
# 977 -0.675522  3.633222 -43.484031 -34.905728
# 978 -0.693770  3.642376 -44.261159 -33.742692
# 979 -1.337111  3.251880 -45.481411 -35.282793
# 980  0.057937  2.080833 -45.822381 -35.329301
# 981  0.421675  1.684977 -45.117125 -36.125921
# 982  1.386282  0.788064 -47.094189 -35.960825
# 983 -0.055373  1.843485 -46.000701 -34.403628
# 984 -0.666481  1.785908 -47.836071 -33.897689
# 985 -0.667668  2.645097 -48.628520 -32.902662
# 986 -1.220343  2.012371 -48.611301 -33.477226
# 987 -2.537486  0.869091 -47.375817 -33.617789
# 988 -2.330425  0.973603 -46.920540 -33.596106
# 989 -3.502756  0.594651 -44.555667 -33.033344
# 990 -3.599015  1.627443 -44.160846 -33.444810
# 991 -2.436417  0.384330 -45.600192 -32.275589
# 992 -2.749606  0.129142 -45.041222 -33.270527
# 993 -2.457621 -0.026389 -45.669013 -32.527948
# 994 -2.389598 -0.488433 -45.313826 -32.926688
# 995 -3.379581  0.384669 -46.959077 -33.869096
# 996 -3.252299 -0.392102 -47.308016 -33.239235
# 997 -2.870151 -1.229096 -48.788108 -34.181542
# 998 -3.766273 -0.441975 -48.595779 -34.275645
# 999 -2.265466 -1.958958 -48.680545 -33.646008
#
# [1000 rows x 4 columns]

# %%
pwd
# Out:
# 'C:\\Users\\Jared\\Desktop'
